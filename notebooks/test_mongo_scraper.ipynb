# %%
from scraper import *
from IPython.display import Image, HTML
pd.set_option('display.max_colwidth', -1)

# %%
s = Scraper()
s.pull()

# %%
HTML(s.data.to_html(escape=False))

# %%
s.data['week plot'].values

# %%
db = MongoDB()

# %%
db.list()
# Out:
# 0: 2017-06-24 09:49:07.785000
# 1: 2017-06-24 09:58:50.304000
# 2: 2017-06-24 10:18:08.833000

# %%
ex_date = db.dates[0]

# %%
db.get(ex_date)
# Out:
# {'1ST': {'active users': 0,
#   'alexa rating': 196527,
#   'bing results': 3190000,
#   'closed issues': 5,
#   'comments per hr': 0.0,
#   'contributors': 1,
#   'dev score': 36,
#   'fb likes': 10019,
#   'forks': 14,
#   'hash': 'N/A',
#   'hash speed': 'N/A',
#   'img': '<img src="https://www.coingecko.com/assets/coin-25/first blood-5532c36f84b4f54cc609dd38f10422d4.png" height="25px" src="https://www.coingecko.com/assets/coin-25/loader-a2d93f439e9b2ffdc23e1c4845fadc9a.png" width="25px"/>',
#   'liquidity': 3796.77,
#   'market cap': 67365.72,
#   'merged pr': 3,
#   'mining hw cost': nan,
#   'name': 'First Blood',
#   'overall score': 49,
#   'percent change': 2.844,
#   'posts per hr': 0.0,
#   'price btc': 0.00078737,
#   'price usd': 2.170012218571675,
#   'recent commits': 0,
#   'search score': 47,
#   'social score': 18,
#   'stars': 36,
#   'subscribers': 0,
#   'total issues': 5,
#   'twitter followers': 5513,
#   'watchers': 6,
# ...
